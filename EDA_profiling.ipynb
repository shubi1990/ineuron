# %%
# pandas_profiling

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Wasu/PycharmProjects/eda/Visadataset.csv")

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_file("pp.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# sweet_viz

# %%
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_html('sv.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sv.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# auto_viz

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df = AV.AutoViz("Visadataset.csv")
# Out:
# Imported AutoViz_Class. Call by using AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Shape of your Data Set: (25480, 12)
# Classifying variables in data set...
#     12 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
# Nothing to add Plot not being added
# Nothing to add Plot not being added
# Time to run AutoViz (in seconds) = 3.040
